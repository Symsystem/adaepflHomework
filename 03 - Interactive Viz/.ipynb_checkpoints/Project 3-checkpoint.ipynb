# %%
import folium
import pandas as pd
import numpy as np

# %%
# Import data from GeoName
import requests
import json

def getData(place):
    base_url = 'http://api.geonames.org/searchJSON'
    payload = {'username': 'adaisp',
               'country' : 'CH',
               'q' : place,
               'fcodeName' : 'university',
                }
    response = requests.get(base_url, params=payload)
    data = json.loads(response.text)
    try:
        i = 0
        results = {
                'canton': data['geonames'][i]['adminCode1'],
                'lat' : data['geonames'][i]['lat'],
                'long' : data['geonames'][i]['lng'],
            }
        while (data['geonames'][i]['adminName1'] == ''):
            i += 1
            results = {
                'canton': data['geonames'][i]['adminCode1'],
                'lat' : data['geonames'][i]['lat'],
                'long' : data['geonames'][i]['lng'],
            }
    except:
        results = {
            'canton': 'No Match',
            'lat' : 'No Match',
            'long' : 'No Match',
        }
        
    return results

# %%
grant_export = 'P3_GrantExport.csv'
raw_data = pd.read_csv(grant_export, sep=';', error_bad_lines=False)

uni_data = raw_data.loc[:, ['University', 'Approved Amount']]
uni_data[['Approved Amount']] = uni_data[['Approved Amount']].apply(pd.to_numeric, errors='coerce')

# drop the records where the field University is blank
uni_data = uni_data[uni_data.University != 'Nicht zuteilbar - NA']

# drop the records corresponding to companies or private sector
uni_data = uni_data[uni_data.University != 'Firmen/Privatwirtschaft - FP']

# drop the records corresponding to NPO
uni_data = uni_data[uni_data.University != 'NPO (Biblioth., Museen, Verwalt.) - NPO']

# we only take into account the Swiss Universities to check if we cover 95% of the records
number_valid_records = len(uni_data)

# compute the approved amount by University
uni_data = uni_data.groupby(['University'])['Approved Amount'].sum()

uni_data.sort_values(ascending=False, inplace=True)

# %%
data = pd.DataFrame(uni_data)
data['Records number'] = raw_data['University'].value_counts()
data['Canton'] = ['']*len(data)
data['Latitude'] = ['']*len(data)
data['Longitude'] = ['']*len(data)

for univ,row in data.iterrows():
    
    info = getData(univ.split(' - ')[0])
    
    if (info.get('canton') == 'No Match' and len(univ.split(' - ')) > 1):
        info = getData(univ.split(' - ')[1])

    data.set_value(univ, 'Canton', info.get('canton'))
    data.set_value(univ, 'Latitude', info.get('lat'))
    data.set_value(univ, 'Longitude', info.get('long'))

# %% [markdown]
# After getting informations from GeoNames API, we have to check if these informations cover at least 95% of the records in the raw_data:
#
# In most of the cases we don't get any information from the API. So we try to find the name of the canton inside the name of the University/Institute. Then, we had to add everything manually.

# %%
# try to look for patterns in the University name
for univ, row in data[data.index.str.contains('Luzern')].iterrows():
    data.set_value(univ, 'Canton', 'LU')
    
for univ, row in data[data.index.str.contains('Zürcher')].iterrows():
    data.set_value(univ, 'Canton', 'ZH')

for univ, row in data[data.index.str.contains('Zürich')].iterrows():
    data.set_value(univ, 'Canton', 'ZH')
    
for univ, row in data[data.index.str.contains('Svizzera italiana')].iterrows():
    data.set_value(univ, 'Canton', 'TI')
    
for univ, row in data[data.index.str.contains('Bern')].iterrows():
    data.set_value(univ, 'Canton', 'BE')

for univ, row in data[data.index.str.contains('St. Gallen')].iterrows():
    data.set_value(univ, 'Canton', 'SG')

for univ, row in data[data.index.str.contains('Vaud')].iterrows():
    data.set_value(univ, 'Canton', 'VD')
    
for univ, row in data[data.index.str.contains('Wallis')].iterrows():
    data.set_value(univ, 'Canton', 'VS')

for univ, row in data[data.index.str.contains('Thurgau')].iterrows():
    data.set_value(univ, 'Canton', 'TG')

data.set_value('HES de Suisse occidentale - HES-SO', 'Canton', 'JU')
data.set_value('Inst. de Hautes Etudes Internat. et du Dév - IHEID', 'Canton', 'GE')
data.set_value('Forschungsanstalten Agroscope - AGS', 'Canton', 'ZH')
data.set_value('Idiap Research Institute - IDIAP', 'Canton', 'VS')
data.set_value('Friedrich Miescher Institute - FMI', 'Canton', 'BS')
data.set_value('Physikal.-Meteorolog. Observatorium Davos - PMOD', 'Canton', 'GR')
data.set_value('Allergie- und Asthmaforschung - SIAF', 'Canton', 'GR')
data.set_value('Swiss Institute of Bioinformatics - SIB', 'Canton', 'VD')
data.set_value('Fachhochschule Ostschweiz - FHO', 'Canton', 'SG')
data.set_value('Inst. universit. romand de Santé au Travail - IST', 'Canton', 'VD')
data.set_value('Schweizer Kompetenzzentrum Sozialwissensch. - FORS', 'Canton', 'VD')
data.set_value('Swiss Center for Electronics and Microtech. - CSEM', 'Canton', 'NE')
data.set_value('Interkant. Hochschule für Heilpädagogik ZH - HfH', 'Canton', 'ZH')
data.set_value('Institut Universitaire Kurt Bösch - IUKB', 'Canton', 'VS')
data.set_value('Ente Ospedaliero Cantonale - EOC', 'Canton', 'TI')
data.set_value('Schweiz. Institut für Kunstwissenschaft - SIK-ISEA', 'Canton', 'ZH')
data.set_value('Pädagogische Hochschule Nordwestschweiz - PHFHNW', 'Canton', 'AG')
data.set_value('AO Research Institute - AORI', 'Canton', 'GR')
data.set_value('Forschungsinstitut für biologischen Landbau - FIBL', 'Canton', 'AG')
data.set_value('Forschungsinstitut für Opthalmologie - IRO', 'Canton', 'VS')
data.set_value('Eidg. Hochschulinstitut für Berufsbildung - EHB', 'Canton', 'BE')
data.set_value('Institut für Kulturforschung Graubünden - IKG', 'Canton', 'GR')
data.set_value('Centre de rech. sur l\'environnement alpin - CREALP', 'Canton', 'VS')
data.set_value('Haute école pédagogique fribourgeoise - HEPFR', 'Canton', 'FR')
data.set_value('Haute école pédagogique BE, JU, NE - HEPBEJUNE', 'Canton', 'JU')
data.set_value('Pädagogische Hochschule Zug - PHZG', 'Canton', 'ZG')
data.set_value('Pädagogische Hochschule Graubünden - PHGR', 'Canton', 'GR')
data.set_value('Robert Walser-Stiftung Bern - RWS', 'Canton', 'BE')
data.set_value('Franklin University Switzerland - FUS', 'Canton', 'TI')
data.set_value('Instituto Ricerche Solari Locarno - IRSOL', 'Canton', 'TI')
data.set_value('Pädagogische Hochschule Schwyz - PHSZ', 'Canton', 'SZ')
data.set_value('Inst. Suisse de Spéléologie et Karstologie - ISSKA', 'Canton', 'NE')
data.set_value('Fachhochschule Kalaidos - FHKD', 'Canton', 'ZH')
data.set_value('Staatsunabh. Theologische Hochschule Basel - STHB', 'Canton', 'BS')
data.set_value('Schweiz. Hochschule für Logopädie Rorschach - SHLR', 'Canton', 'SG')
data.set_value('Pädagogische Hochschule Wallis - PHVS', 'Canton', 'VS')
data.set_value('Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP', 'Canton', 'TI')
data.set_value('Facoltà di Teologia di Lugano - FTL', 'Canton', 'TI')
data.set_value('Pädagogische Hochschule Schaffhausen - PHSH', 'Canton', 'SH')
data.set_value('Forschungskommission SAGW', 'Canton', 'BE')
data.set_value('Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS', 'Canton', 'VS')
# Out:
#                                                     Approved Amount  \
# University
# Université de Genève - GE                              1.838237e+09
# Universität Zürich - ZH                                1.826843e+09
# ETH Zürich - ETHZ                                      1.635597e+09
# Universität Bern - BE                                  1.519373e+09
# Universität Basel - BS                                 1.352251e+09
# Université de Lausanne - LA                            1.183291e+09
# EPF Lausanne - EPFL                                    1.175316e+09
# Université de Fribourg - FR                            4.575262e+08
# Université de Neuchâtel - NE                           3.832046e+08
# Paul Scherrer Institut - PSI                           1.152690e+08
# Università della Svizzera italiana - USI               8.497055e+07
# Eidg. Anstalt für Wasserversorgung - EAWAG             7.461922e+07
# Universität St. Gallen - SG                            6.919495e+07
# Eidg. Material und Prüfungsanstalt - EMPA              5.857452e+07
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL     4.836039e+07
# Zürcher Fachhochschule (ohne PH) - ZFH                 4.484345e+07
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW        4.277191e+07
# Friedrich Miescher Institute - FMI                     4.022914e+07
# Universität Luzern - LU                                3.998168e+07
# Inst. de Hautes Etudes Internat. et du Dév - IHEID     3.886423e+07
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS     3.473582e+07
# HES de Suisse occidentale - HES-SO                     3.416297e+07
# Forschungsanstalten Agroscope - AGS                    3.311572e+07
# Berner Fachhochschule - BFH                            3.102870e+07
# SUP della Svizzera italiana - SUPSI                    2.404008e+07
# Idiap Research Institute - IDIAP                       2.218311e+07
# Allergie- und Asthmaforschung - SIAF                   1.916996e+07
# Swiss Center for Electronics and Microtech. - CSEM     1.806825e+07
# Kantonsspital St. Gallen - KSPSG                       1.503410e+07
# Physikal.-Meteorolog. Observatorium Davos - PMOD       1.209844e+07
# ...                                                             ...
# Biotechnologie Institut Thurgau - BITG                 2.492535e+06
# Pädagogische Hochschule St. Gallen - PHSG              2.098387e+06
# Eidg. Hochschulinstitut für Berufsbildung - EHB        2.086572e+06
# Pädagogische Hochschule Bern - PHBern                  1.990390e+06
# Pädagogische Hochschule Luzern - PHLU                  1.979281e+06
# Institut Universitaire Kurt Bösch - IUKB               1.977340e+06
# Schweizer Paraplegiker Forschung - SPF                 1.944211e+06
# Centre de rech. sur l'environnement alpin - CREALP     1.567678e+06
# Haute école pédagogique fribourgeoise - HEPFR          1.547498e+06
# Pädagogische Hochschule Thurgau - PHTG                 1.526446e+06
# Haute école pédagogique du canton de Vaud - HEPL       1.430686e+06
# Institut für Kulturforschung Graubünden - IKG          1.219681e+06
# Fachhochschule Kalaidos - FHKD                         1.090280e+06
# Instituto Ricerche Solari Locarno - IRSOL              9.512380e+05
# Pädagogische Hochschule Schwyz - PHSZ                  9.365510e+05
# Haute école pédagogique BE, JU, NE - HEPBEJUNE         6.273800e+05
# Inst. Suisse de Spéléologie et Karstologie - ISSKA     6.248190e+05
# Pädagogische Hochschule Graubünden - PHGR              6.146130e+05
# Robert Walser-Stiftung Bern - RWS                      5.695790e+05
# Pädagogische Hochschule Zug - PHZG                     4.957150e+05
# Schweiz. Hochschule für Logopädie Rorschach - SHLR     4.296000e+05
# Pädagogische Hochschule Wallis - PHVS                  4.254980e+05
# Pädagogische Hochschule Schaffhausen - PHSH            1.766910e+05
# Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP      1.593170e+05
# Istituto Svizzero di Roma - ISR                        1.410000e+05
# Forschungskommission SAGW                              1.000000e+05
# Franklin University Switzerland - FUS                  6.595600e+04
# Staatsunabh. Theologische Hochschule Basel - STHB      1.730000e+04
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS     1.200000e+04
# Facoltà di Teologia di Lugano - FTL                    8.000000e+03
#
#                                                     Records number    Canton  \
# University
# Université de Genève - GE                                     6394        GE
# Universität Zürich - ZH                                       6774        ZH
# ETH Zürich - ETHZ                                             6153        ZH
# Universität Bern - BE                                         5473        BE
# Universität Basel - BS                                        4746        BS
# Université de Lausanne - LA                                   4092        VD
# EPF Lausanne - EPFL                                           4428        VD
# Université de Fribourg - FR                                   2079        FR
# Université de Neuchâtel - NE                                  1596        NE
# Paul Scherrer Institut - PSI                                   538        AG
# Università della Svizzera italiana - USI                       346        TI
# Eidg. Anstalt für Wasserversorgung - EAWAG                     333        ZH
# Universität St. Gallen - SG                                    426        SG
# Eidg. Material und Prüfungsanstalt - EMPA                      238        ZH
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL             223        ZH
# Zürcher Fachhochschule (ohne PH) - ZFH                         260        ZH
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW                228        BL
# Friedrich Miescher Institute - FMI                              84        BS
# Universität Luzern - LU                                        214        LU
# Inst. de Hautes Etudes Internat. et du Dév - IHEID             198        GE
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS              31        VD
# HES de Suisse occidentale - HES-SO                             271        JU
# Forschungsanstalten Agroscope - AGS                            135        ZH
# Berner Fachhochschule - BFH                                    136        BE
# SUP della Svizzera italiana - SUPSI                            135        TI
# Idiap Research Institute - IDIAP                                88        VS
# Allergie- und Asthmaforschung - SIAF                            44        GR
# Swiss Center for Electronics and Microtech. - CSEM              28        NE
# Kantonsspital St. Gallen - KSPSG                                48        SG
# Physikal.-Meteorolog. Observatorium Davos - PMOD                48        GR
# ...                                                            ...       ...
# Biotechnologie Institut Thurgau - BITG                           8        TG
# Pädagogische Hochschule St. Gallen - PHSG                       13        SG
# Eidg. Hochschulinstitut für Berufsbildung - EHB                 12        BE
# Pädagogische Hochschule Bern - PHBern                           13        BE
# Pädagogische Hochschule Luzern - PHLU                           14        LU
# Institut Universitaire Kurt Bösch - IUKB                        21        VS
# Schweizer Paraplegiker Forschung - SPF                          10        LU
# Centre de rech. sur l'environnement alpin - CREALP               8        VS
# Haute école pédagogique fribourgeoise - HEPFR                    7        FR
# Pädagogische Hochschule Thurgau - PHTG                           6        TG
# Haute école pédagogique du canton de Vaud - HEPL                16        VD
# Institut für Kulturforschung Graubünden - IKG                   12        GR
# Fachhochschule Kalaidos - FHKD                                   3        ZH
# Instituto Ricerche Solari Locarno - IRSOL                        5        TI
# Pädagogische Hochschule Schwyz - PHSZ                            5        SZ
# Haute école pédagogique BE, JU, NE - HEPBEJUNE                   7        JU
# Inst. Suisse de Spéléologie et Karstologie - ISSKA               3        NE
# Pädagogische Hochschule Graubünden - PHGR                        7        GR
# Robert Walser-Stiftung Bern - RWS                                6        BE
# Pädagogische Hochschule Zug - PHZG                               7        ZG
# Schweiz. Hochschule für Logopädie Rorschach - SHLR               2        SG
# Pädagogische Hochschule Wallis - PHVS                            2        VS
# Pädagogische Hochschule Schaffhausen - PHSH                      1        SH
# Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP                2        TI
# Istituto Svizzero di Roma - ISR                                  6  No Match
# Forschungskommission SAGW                                        1        BE
# Franklin University Switzerland - FUS                            6        TI
# Staatsunabh. Theologische Hochschule Basel - STHB                3        BS
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS               1        VS
# Facoltà di Teologia di Lugano - FTL                              2        TI
#
#                                                     Latitude Longitude
# University
# Université de Genève - GE                           46.20222   6.14569
# Universität Zürich - ZH                             47.37092   8.53434
# ETH Zürich - ETHZ                                    47.3763   8.54805
# Universität Bern - BE                               46.95096   7.43548
# Universität Basel - BS                              47.55832   7.58403
# Université de Lausanne - LA                         46.52376   6.58409
# EPF Lausanne - EPFL                                 46.51939   6.56673
# Université de Fribourg - FR                         46.80683   7.15317
# Université de Neuchâtel - NE                        46.99385   6.93789
# Paul Scherrer Institut - PSI                         47.5385   8.23028
# Università della Svizzera italiana - USI            No Match  No Match
# Eidg. Anstalt für Wasserversorgung - EAWAG          47.40311   8.61246
# Universität St. Gallen - SG                         47.42391   9.37477
# Eidg. Material und Prüfungsanstalt - EMPA           47.40311   8.61246
# Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL  47.36044   8.45484
# Zürcher Fachhochschule (ohne PH) - ZFH              No Match  No Match
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW     47.53378   7.63856
# Friedrich Miescher Institute - FMI                  No Match  No Match
# Universität Luzern - LU                             47.05048   8.30635
# Inst. de Hautes Etudes Internat. et du Dév - IHEID  No Match  No Match
# Schweizer Kompetenzzentrum Sozialwissensch. - FORS  No Match  No Match
# HES de Suisse occidentale - HES-SO                  No Match  No Match
# Forschungsanstalten Agroscope - AGS                 No Match  No Match
# Berner Fachhochschule - BFH                         No Match  No Match
# SUP della Svizzera italiana - SUPSI                 46.02394   8.91741
# Idiap Research Institute - IDIAP                    No Match  No Match
# Allergie- und Asthmaforschung - SIAF                No Match  No Match
# Swiss Center for Electronics and Microtech. - CSEM  No Match  No Match
# Kantonsspital St. Gallen - KSPSG                    47.42925   9.38826
# Physikal.-Meteorolog. Observatorium Davos - PMOD    No Match  No Match
# ...                                                      ...       ...
# Biotechnologie Institut Thurgau - BITG              No Match  No Match
# Pädagogische Hochschule St. Gallen - PHSG           No Match  No Match
# Eidg. Hochschulinstitut für Berufsbildung - EHB     No Match  No Match
# Pädagogische Hochschule Bern - PHBern               No Match  No Match
# Pädagogische Hochschule Luzern - PHLU               No Match  No Match
# Institut Universitaire Kurt Bösch - IUKB            No Match  No Match
# Schweizer Paraplegiker Forschung - SPF              46.95161   8.01723
# Centre de rech. sur l'environnement alpin - CREALP  No Match  No Match
# Haute école pédagogique fribourgeoise - HEPFR       No Match  No Match
# Pädagogische Hochschule Thurgau - PHTG              No Match  No Match
# Haute école pédagogique du canton de Vaud - HEPL    No Match  No Match
# Institut für Kulturforschung Graubünden - IKG       No Match  No Match
# Fachhochschule Kalaidos - FHKD                      No Match  No Match
# Instituto Ricerche Solari Locarno - IRSOL           No Match  No Match
# Pädagogische Hochschule Schwyz - PHSZ               No Match  No Match
# Haute école pédagogique BE, JU, NE - HEPBEJUNE      No Match  No Match
# Inst. Suisse de Spéléologie et Karstologie - ISSKA  No Match  No Match
# Pädagogische Hochschule Graubünden - PHGR           No Match  No Match
# Robert Walser-Stiftung Bern - RWS                   No Match  No Match
# Pädagogische Hochschule Zug - PHZG                  No Match  No Match
# Schweiz. Hochschule für Logopädie Rorschach - SHLR  No Match  No Match
# Pädagogische Hochschule Wallis - PHVS               No Match  No Match
# Pädagogische Hochschule Schaffhausen - PHSH         No Match  No Match
# Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP   47.44496   8.05034
# Istituto Svizzero di Roma - ISR                     No Match  No Match
# Forschungskommission SAGW                           No Match  No Match
# Franklin University Switzerland - FUS               No Match  No Match
# Staatsunabh. Theologische Hochschule Basel - STHB   No Match  No Match
# Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS  No Match  No Match
# Facoltà di Teologia di Lugano - FTL                 No Match  No Match
#
# [74 rows x 5 columns]

# %% [markdown]
# We see that after filling the dataframe, we have more than 95% of the cantons that are covered. So we stop there.

# %%
canton_found = data[data.Canton != 'No Match']
percentage = len(canton_found) / len(data)

percentage
# Out:
# 0.9594594594594594

# %% [markdown]
# Now we create the dataframe containing the total approved amount for each canton. If there is no entry for a canton in the dataframe, we just put 0.

# %%
all_cantons = np.array(['AG','AI','AR','BE','BL','BS','FR','GE','GL','GR','LU',
                        'NE','NW','OW','SG','SO','SZ','TG','TI','UR','VD','VS','ZG','ZH','SH','JU'])
amounts = canton_found.groupby(['Canton'])['Approved Amount'].sum()

cantons_amount = []
for canton in all_cantons:
    if amounts.get(canton):
        cantons_amount.append(np.log10(amounts.get(canton)))
    else:
        cantons_amount.append(0)

cantons_amount_df = pd.DataFrame()
cantons_amount_df['Canton'] = all_cantons
cantons_amount_df['Amount'] = cantons_amount

# %% [markdown]
# To place markers on the map, we also create a dataframe containing the universities / institutes that have coordinates coming from the geonames API.
# We can see that only 20 places are found by the API.

# %%
univ_found_api = canton_found[canton_found.Latitude != 'No Match']
univ_found_api.shape
# Out:
# (20, 5)

# %%
cantons_geo = 'ch-cantons.topojson.json'

swiss_map = folium.Map(location=[46.801111,8.226667], zoom_start=8)

for univ, row in univ_found_api.iterrows():
     folium.Marker([row['Latitude'], row['Longitude']],
                   popup=univ, 
                   icon = folium.Icon(color = 'red', icon = 'glyphicon-book')).add_to(swiss_map)

swiss_map.choropleth(geo_path=cantons_geo, 
                     topojson='objects.cantons', 
                     data=cantons_amount_df,columns=['Canton', 'Amount'],
                     key_on='feature.id',
                     threshold_scale=[4, 5, 6, 7, 8, 9],
                     line_opacity=0.2, fill_opacity=0.7, fill_color='YlOrBr',
                     legend_name='Approved amount (logarithmic scale)',
                    )
swiss_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
swiss_map.save("map_manual.html")
