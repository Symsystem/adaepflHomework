# %%
import folium
import pandas as pd

cantons = 'ch-cantons.topojson.json'
grant_export = 'P3_GrantExport.csv'
data  = pd.read_csv(grant_export, sep=';', error_bad_lines=False)


print(data.shape)
# Out:
# (63969, 15)

# %%
L = []
for st in data['University'] :
    a=str(st).split(" - ")
    if len(a) > 1 :
        L.append( str(st).split(" - ")[1])
    else :
        L.append('NaN')
data['Shortcode Uni'] = L

# %%
count_university = data['Shortcode Uni'].value_counts()

# %%
df = pd.DataFrame(data=count_university)
df.head(100)
# Out:
#            Shortcode Uni
# NaN                12982
# ZH                  6774
# GE                  6394
# ETHZ                6153
# BE                  5473
# BS                  4746
# EPFL                4428
# LA                  4092
# NA                  2595
# FR                  2079
# NE                  1596
# NPO                 1473
# PSI                  538
# FP                   492
# SG                   426
# USI                  346
# EAWAG                333
# HES-SO               271
# ZFH                  260
# EMPA                 238
# FHNW                 228
# WSL                  223
# LU                   214
# IHEID                198
# BFH                  136
# AGS                  135
# SUPSI                135
# IDIAP                 88
# FMI                   84
# ASPIT                 81
# ...                  ...
# AORI                  17
# HEPL                  16
# PHLU                  14
# IRO                   14
# PHSG                  13
# ...

# %%
#Let Folium determine the scale
map = folium.Map(location=[47, 8], zoom_start=3)
#map.choropleth(geo_path =cantons ,topojson=cantons)


map.choropleth(geo_path=cantons, data=df,
              key_on='feature.id',
              fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2,
              legend_name='Test')

#you have to save the map in an htlm ...
map.save('test.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-26f6ca2c54e2> in <module>()
#       7               key_on='feature.id',
#       8               fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2,
# ----> 9               legend_name='Test')
#      10
#      11 #you have to save the map in an htlm ...
#
# C:\Users\francois\Anaconda3\lib\site-packages\folium\folium.py in choropleth(self, geo_path, geo_str, data_out, data, columns, key_on, threshold_scale, fill_color, fill_opacity, line_color, line_weight, line_opacity, legend_name, topojson, reset)
#     613         if hasattr(data, 'set_index'):
#     614             # This is a pd.DataFrame
# --> 615             color_data = data.set_index(columns[0])[columns[1]].to_dict()
#     616         elif hasattr(data, 'to_dict'):
#     617             # This is a pd.Series
#
# ...
