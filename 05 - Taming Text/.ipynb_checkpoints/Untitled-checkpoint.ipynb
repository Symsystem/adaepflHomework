# %%
# ADA LAST HOMEWORK :D

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
# %matplotlib inline
from os import path
from wordcloud import WordCloud
from nltk.corpus import stopwords

# %%
path_email = 'hillary-clinton-emails/Emails.csv'
file = pd.read_csv(path_email,usecols=['ExtractedSubject','ExtractedBodyText','RawText'])
file.drop(['RawText'], axis= 1,inplace=True)

def extractSubjectAndText(row):
    text = '' if pd.isnull(row.ExtractedBodyText) else row.ExtractedBodyText
    subject = '' if pd.isnull(row.ExtractedSubject) else row.ExtractedSubject
    return subject + text

email_content = pd.DataFrame()
email_content['text'] = file.apply(extractSubjectAndText, axis=1)
email_content.head()
text = ' '.join(email_content['text'])

# %%
### first cloud word
# word cloud image
wordcloud_image = WordCloud().generate(text)

# Display the generated image
plt.imshow(wordcloud_image)
plt.title('Word Cloud')

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis('off' )
plt.title('Word Cloud')
plt.show()

# %%
# Our Pipeline

# Tokenization : In lexical analysis, tokenization is the process of breaking a stream of text up into words,
#phrases, symbols, or other meaningful elements called tokens. The list of tokens becomes input for further 
#processing such as parsing or text mining. Tokenization is useful both in linguistics (where it is a form of 
#text segmentation), and in computer science, where it forms part of lexical analysis.
#nltk.download() # needed :D once ?
### next cell takes a lot of time :D

# %%
# Tokenization \n ,
import string
from nltk import word_tokenize
text_tokened = [i for i in word_tokenize(text.lower())]

stop = set(stopwords.words('english'))
stop.extend(["n't", 'pm'])
stop.update(string.punctuation) #Remove ponctuation
body_updated_tokenized = [i for i in word_tokenize(text.lower()) if i not in stop]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-10-95110cdb4119> in <module>()
#       2 import string
#       3 from nltk import word_tokenize
# ----> 4 text_tokened = [i for i in word_tokenize(text.lower())]
#       5
#       6 stop = set(stopwords.words('english'))
#
# /Users/Sym/anaconda/lib/python3.5/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     return [token for sent in sent_tokenize(text, language)
#     107             for token in _treebank_word_tokenize(sent)]
#     108
#
# /Users/Sym/anaconda/lib/python3.5/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      88     :param language: the model name in the Punkt corpus
#      89     """
# ---> 90     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#      91     return tokenizer.tokenize(text)
#      92
#
# /Users/Sym/anaconda/lib/python3.5/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     799
#     800     # Load the resource.
# --> 801     opened_resource = _open(resource_url)
#     802
#     803     if format == 'raw':
#
# /Users/Sym/anaconda/lib/python3.5/site-packages/nltk/data.py in _open(resource_url)
#     917
#     918     if protocol is None or protocol.lower() == 'nltk':
# --> 919         return find(path_, path + ['']).open()
#     920     elif protocol.lower() == 'file':
#     921         # urllib might not use mode='rb', so handle this one ourselves:
#
# /Users/Sym/anaconda/lib/python3.5/site-packages/nltk/data.py in find(resource_name, paths)
#     639     sep = '*' * 70
#     640     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 641     raise LookupError(resource_not_found)
#     642
#     643
#
# LookupError:
# **********************************************************************
#   Resource 'tokenizers/punkt/PY3/english.pickle' not found.
#   Please use the NLTK Downloader to obtain the resource:  >>>
#   nltk.download()
#   Searched in:
#     - '/Users/Sym/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import collections

# we are processing .... the data !!!! two ways : lemmatized and stemming

porter = PorterStemmer()  #http://www.nltk.org/api/nltk.stem.html
wnl = WordNetLemmatizer()

stemmed = [porter.stem(token) for token in body_updated_tokenized]
lemmatized = [wnl.lemmatize(token) for token in body_updated_tokenized]

# %%
newText = ' '.join(lemmatized)
# lower max_font_size\n ,
wordcloud = WordCloud(max_font_size=40).generate(newText)
plt.figure()
plt.imshow(wordcloud)
plt.axis('off' )
plt.title('Pre-processed text')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8afe5316bf7b> in <module>()
# ----> 1 newText = ' '.join(lemmatized)
#       2 # lower max_font_size\n ,
#       3 wordcloud = WordCloud(max_font_size=40).generate(newText)
#       4 plt.figure()
#       5 plt.imshow(wordcloud)
#
# NameError: name 'lemmatized' is not defined

# %%
## 22
import pycountry

# %%
for country in list(pycountry.countries)[:10]:
    print(country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e7a6eb023ffc> in <module>()
# ----> 1 for country in list(pycountry.countries)[:10]:
#       2     print(country)
#
# NameError: name 'pycountry' is not defined
