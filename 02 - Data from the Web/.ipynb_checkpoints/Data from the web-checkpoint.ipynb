# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
data = []

pedago_period = [249108, 942175]
semesters = ['semester 1', 'semester 6']
acad_period = [978181, 978187, 978195, 39486325, 123455150, 123456101, 213637754, 213637922, 213638028, 355925344]
years = ['2007-2008','2008-2009','2009-2010', '2010-2011', '2011-2012', '2012-2013', '2013-2014', '2014-2015', '2015-2016', '2016-2017']

for pedago in pedago_period:
    for acad in acad_period:
        payload = {'ww_x_GPS': '-1',
                   'ww_i_reportModel': 133685247,
                   'ww_i_reportModelXsl': 133685270,
                   'ww_x_UNITE_ACAD': 249847,
                   'ww_x_PERIODE_ACAD': acad,
                   'ww_x_PERIODE_PEDAGO': pedago,
                   'ww_x_HIVERETE': 'null'
                  }
        data.append(requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html', params=payload))

# %%
soupSemester1 = []
for i in range(0, 10):
    soupSemester1.append(BeautifulSoup(data[i].text, 'html.parser'))

soupSemester6 = []
for i in range(10, 20):
    soupSemester6.append(BeautifulSoup(data[i].text, 'html.parser'))

# %%
from math import floor

students = []
i = 0
for fsoup in soups:
    for tr in fsoup.html.body.hr.table.findAll('tr'):
        tds = tr.findAll('td')
        if (len(tds) > 0):
            student = {'civilite': tds[0].text,
                       'name': tds[1].text,
                       'sciper': tds[10].text,
                       'year': years[i%10],
                       'semester': semesters[floor(i/10)]
                      }
            students.append(student)
    i += 1
    if (i == 10):
        students_sem1 = pd.DataFrame(students)
        students = []
    if (i == 20):
        students_sem6 = pd.DataFrame(students)

students_sem6.drop('civilite', axis=1, inplace=True)
students_sem6.drop('name', axis=1, inplace=True)
        
#students = students_sem1.join()


students_sem1.drop_duplicates(subset=['sciper'], keep='first', inplace=True)
students_sem1.set_index(['sciper'], inplace=True)

students_sem6.drop_duplicates(subset=['sciper'], keep='last', inplace=True)
students_sem6.set_index(['sciper'], inplace=True)

pd.concat([students_sem1, students_sem6], axis=1, join='inner')
# Out:
#         civilite                                  name    semester       year  \
# sciper
# 169569  Monsieur                     Arévalo Christian  semester 1  2007-2008
# 179449  Monsieur                 Bindschaedler Vincent  semester 1  2007-2008
# 178553  Monsieur                    Bloch Marc-Olivier  semester 1  2007-2008
# 178271  Monsieur                Boéchat Marc-Alexandre  semester 1  2007-2008
# 180731  Monsieur                  Bricola Jean-Charles  semester 1  2007-2008
# 171619  Monsieur                  Buchschacher Nicolas  semester 1  2007-2008
# 178786  Monsieur                          Coiro Andrea  semester 1  2007-2008
# 178656  Monsieur                     Curreli Alexandre  semester 1  2007-2008
# 178706    Madame                   Falbriard Stéphanie  semester 1  2007-2008
# 181121  Monsieur                            Frund Loïc  semester 1  2007-2008
# 180570  Monsieur                          Habfast Paul  semester 1  2007-2008
# 175190  Monsieur                       Hanser Valérian  semester 1  2007-2008
# 181248  Monsieur                        Helfer Etienne  semester 1  2007-2008
# 178433  Monsieur                     Leuenberger Johan  semester 1  2007-2008
# 181298  Monsieur                          Lütolf Lukas  semester 1  2007-2008
# 181115  Monsieur     Miraglia Franco de Carvalho Pedro  semester 1  2007-2008
# 180094  Monsieur                           Mirza Elias  semester 1  2007-2008
# 181017  Monsieur                         Nötzli Andres  semester 1  2007-2008
# 179194  Monsieur                         Obrist Damien  semester 1  2007-2008
# 179988    Madame                       Portmann Joëlle  semester 1  2007-2008
# 180959  Monsieur                      Restani Stéphane  semester 1  2007-2008
# 171195  Monsieur                        Richter Arnaud  semester 1  2007-2008
# 178948  Monsieur                      Schädeli Andreas  semester 1  2007-2008
# 178684  Monsieur                        Schwery Thomas  semester 1  2007-2008
# 180241  Monsieur                 Sondag Pierre-Antoine  semester 1  2007-2008
# 180854  Monsieur                       Vautherin Jonas  semester 1  2007-2008
# 178682  Monsieur                          Zoller Roman  semester 1  2007-2008
# 184772  Monsieur                         Arnfred Jonas  semester 1  2008-2009
# 179406  Monsieur                    Baeriswyl Jonathan  semester 1  2007-2008
# 179428  Monsieur                       Barroco Michael  semester 1  2007-2008
# ...          ...                                   ...         ...        ...
# 235117  Monsieur    Tournigand Guillaume Nicolas Louis  semester 1  2013-2014
# 212686  Monsieur                  Urien Thibault Félix  semester 1  2012-2013
# 226658  Monsieur                        Weiskopf Robin  semester 1  2012-2013
# 212826  Monsieur                       Willemin Xavier  semester 1  2011-2012
# 227775  Monsieur                 Wirz Leonardo Enrique  semester 1  2012-2013
# 237151  Monsieur                  Zbinden Boris Adrien  semester 1  2013-2014
# 226652  Monsieur                 Zenhäusern Joey Kevin  semester 1  2012-2013
# 246671  Monsieur                    Abate Bryan Jeremy  semester 1  2014-2015
# 251759  Monsieur                     Alami-Idrissi Ali  semester 1  2014-2015
# 249498  Monsieur                         Aoun Leonardo  semester 1  2014-2015
# 234551  Monsieur              Bachmann Roman Christian  semester 1  2014-2015
# 247328  Monsieur                  Beck Johannes Magnus  semester 1  2014-2015
# 251758  Monsieur                          Benlalah Ali  semester 1  2014-2015
# 250300  Monsieur              Bovel Matthieu Alexandre  semester 1  2014-2015
# 249954  Monsieur      Burgelin Clément Louis Alexandre  semester 1  2014-2015
# 249996  Monsieur                  Coudert Rémi Edouard  semester 1  2014-2015
# 239489    Madame                       Evrova Gabriela  semester 1  2014-2015
# 246663  Monsieur                   Haefeli Simon Lucas  semester 1  2014-2015
# 245511  Monsieur                         Lamonato Yves  semester 1  2014-2015
# 250703  Monsieur              Madillo Raphael Frederic  semester 1  2014-2015
# 245512  Monsieur             Massemin Lucas Christophe  semester 1  2014-2015
# 247855  Monsieur     Mösching Guillaume Edouard Albert  semester 1  2014-2015
# 227311    Madame  Mollier Lauriane Catherine Emilienne  semester 1  2013-2014
# 245782  Monsieur                        Perret Thibaud  semester 1  2014-2015
# 247233  Monsieur                         Ramirez Lucas  semester 1  2014-2015
# 225452  Monsieur                           Resin David  semester 1  2012-2013
# 250362  Monsieur                Rigori Valentin Joseph  semester 1  2014-2015
# 247680  Monsieur                            Soufi Raja  semester 1  2014-2015
# 246532  Monsieur                 Vaucher Timoté Pascal  semester 1  2014-2015
# 247891  Monsieur                        Weier Philippe  semester 1  2014-2015
#
#           semester       year
# sciper
# 169569  semester 6  2009-2010
# 179449  semester 6  2009-2010
# 178553  semester 6  2009-2010
# 178271  semester 6  2009-2010
# 180731  semester 6  2009-2010
# 171619  semester 6  2009-2010
# 178786  semester 6  2009-2010
# 178656  semester 6  2009-2010
# 178706  semester 6  2009-2010
# 181121  semester 6  2009-2010
# 180570  semester 6  2009-2010
# 175190  semester 6  2009-2010
# 181248  semester 6  2009-2010
# 178433  semester 6  2009-2010
# 181298  semester 6  2009-2010
# 181115  semester 6  2009-2010
# 180094  semester 6  2009-2010
# 181017  semester 6  2009-2010
# 179194  semester 6  2009-2010
# 179988  semester 6  2009-2010
# 180959  semester 6  2009-2010
# 171195  semester 6  2009-2010
# 178948  semester 6  2009-2010
# 178684  semester 6  2009-2010
# 180241  semester 6  2009-2010
# 180854  semester 6  2009-2010
# 178682  semester 6  2009-2010
# 184772  semester 6  2010-2011
# 179406  semester 6  2010-2011
# 179428  semester 6  2010-2011
# ...            ...        ...
# 235117  semester 6  2015-2016
# 212686  semester 6  2015-2016
# 226658  semester 6  2015-2016
# 212826  semester 6  2015-2016
# 227775  semester 6  2015-2016
# 237151  semester 6  2015-2016
# 226652  semester 6  2015-2016
# 246671  semester 6  2016-2017
# 251759  semester 6  2016-2017
# 249498  semester 6  2016-2017
# 234551  semester 6  2016-2017
# 247328  semester 6  2016-2017
# 251758  semester 6  2016-2017
# 250300  semester 6  2016-2017
# 249954  semester 6  2016-2017
# 249996  semester 6  2016-2017
# 239489  semester 6  2016-2017
# 246663  semester 6  2016-2017
# 245511  semester 6  2016-2017
# 250703  semester 6  2016-2017
# 245512  semester 6  2016-2017
# 247855  semester 6  2016-2017
# 227311  semester 6  2016-2017
# 245782  semester 6  2016-2017
# 247233  semester 6  2016-2017
# 225452  semester 6  2016-2017
# 250362  semester 6  2016-2017
# 247680  semester 6  2016-2017
# 246532  semester 6  2016-2017
# 247891  semester 6  2016-2017
#
# [397 rows x 6 columns]
