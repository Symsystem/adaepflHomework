# %% [markdown]
# ## Libraries to import ##

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests

from bs4 import BeautifulSoup

# %% [markdown]
# ## Functions used in exercises 1 and 2
#
# Since the process of collecting data from IS-Academia is almost the same for bachelor and master students, we define functions that we later use for both exercises.
#
# First of all, here is the function that collects the raw data from the server. It returns the BeautifulSoup HTML file with all the students registered in the year and the semester given in the parameters.

# %%
def getRawData(year, sem):
    payload = {'ww_x_GPS': '-1',
               'ww_i_reportModel': 133685247,
               'ww_i_reportModelXsl': 133685270,
               'ww_x_UNITE_ACAD': 249847,
               'ww_x_PERIODE_ACAD': year,
               'ww_x_PERIODE_PEDAGO': sem,
               'ww_x_HIVERETE': 'null'
              }

    data = requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html', params=payload)
    return BeautifulSoup(data.text, 'html.parser')

# %% [markdown]
# The next function uses raw data from the previous function and structures them to obtain a list of students. Each student is a dictionary with the following properties: civility, name, sciper, academic year, semester, minor and the specialization.

# %%
def getStructuredData(year, sem):
    raw_data = getRawData(year, sem)
    students = []
    
    for tr in raw_data.html.body.hr.table.findAll('tr'):
        tds = tr.findAll('td')
        if (len(tds) > 0):
            student = {
                'civility': tds[0].text,
                'name': tds[1].text,
                'sciper': tds[10].text,
                'academic year': all_years.get(year),
                'semester': all_semesters.get(sem),
                'minor': tds[6].text,
                'specialization': tds[4].text
                }
            students.append(student)
    return students

# %% [markdown]
# Now, to make it easy, we create a function "getDataFrame" that returns a pandas dataframe with all the students registered for the years in the list "years" and for the semesters in the list "semesters", both passed in parameters.

# %%
def getDataFrame(years, semesters):
    results = []
    
    for year in years:
        for sem in semesters:
            results.extend(getStructuredData(year, sem))
    
    return pd.DataFrame(results)

# %% [markdown]
# Finally we create 2 dictionaries that associate the request's code of each kind of semester to their nomination and the same for academic years.
# Moreover, to create a kind of bijection between the name and the code, we create a function getCode.

# %%
all_semesters = {
    249108: 'bachelor1',
    942175: 'bachelor6',
    2230106: 'master1',
    942192: 'master2',
    2230128: 'master3',
    249127: 'project_autumn',
    3781783: 'project_spring'
}

all_years = {
    978181: '2007-2008',
    978187: '2008-2009',
    978195: '2009-2010',
    39486325: '2010-2011',
    123455150: '2011-2012',
    123456101: '2012-2013',
    213637754: '2013-2014',
    213637922: '2014-2015',
    213638028: '2015-2016',
    355925344: '2016-2017'
}

def getCode(dictionary, value):
    for code, name in dictionary.items():
        if name == value:
            return code

# %% [markdown]
# # Exercise 1

# %% [markdown]
# We start by collecting all the data regarding students attending Bachelor Semester 1 and Bachelor Semester 6. We store the data in two DataFrames: student_bac1 and student_bac6.

# %%
# ==================================================================================
# /!\ Quite slow to get the data, so try to not execute this cell too many times /!\
# ==================================================================================

student_bac1 = getDataFrame(all_years, [getCode(all_semesters, 'bachelor1')])
student_bac6 = getDataFrame(all_years, [getCode(all_semesters, 'bachelor6')])

# %% [markdown]
# Since a student might repeat some Semesters, we first sort them by academic year and then, for each student, we keep the first record regarding the Bachelor Semester 1 and the last record regarding Bachelor Semester 6. We assume a student always starts the Bachelor studies at Semester 1 and always finishes at Semester 6.
#
# By dropping the duplicates we guarantee that the SCIPER number can be used as an index for both DataFrames and we can then use an inner join to concatenate them. Before concatenating we drop some columns to avoid redundant data.

# %%
student_bac1.sort_values('academic year', inplace=True)
student_bac6.sort_values('academic year', inplace=True)

student_bac1.drop_duplicates(subset=['sciper'], keep='first', inplace=True)
student_bac6.drop_duplicates(subset=['sciper'], keep='last', inplace=True)

student_bac1.set_index(['sciper'], inplace=True)
student_bac6.set_index(['sciper'], inplace=True)

student_bac1.drop('minor', axis=1, inplace=True)
student_bac1.drop('specialization', axis=1, inplace=True)
student_bac1.drop('semester', axis=1, inplace=True)

student_bac6 = student_bac6.loc[:, ['academic year']]

student_bac1.columns = ['arrival year', 'civility', 'name']
student_bac6.columns = ['graduation year']

students = pd.concat([student_bac1, student_bac6], axis=1, join='inner')

# %% [markdown]
# By doing an inner join we guarantee that all students present in the new DataFrame have valid data when it comes to their first year at EPFL and their graduation year.
# To compute the duration of their stay at EPFL during their Bachelor studies we must do some parsing since both years appear as academic years. The academic years are also stored as a string, so a conversion to integer must take place.

# %%
students = students[['civility', 'name', 'arrival year', 'graduation year']]

students['duration'] = [int(dep.split("-")[1]) - int(arr.split("-")[0])
                        for arr, dep in students[['arrival year', 'graduation year']].values]

students.head(25)
# Out:
#         civility                               name arrival year  \
# sciper
# 169569  Monsieur                  Arévalo Christian    2007-2008
# 180570  Monsieur                       Habfast Paul    2007-2008
# 175190  Monsieur                    Hanser Valérian    2007-2008
# 181298  Monsieur                       Lütolf Lukas    2007-2008
# 181248  Monsieur                     Helfer Etienne    2007-2008
# 178433  Monsieur                  Leuenberger Johan    2007-2008
# 180731  Monsieur               Bricola Jean-Charles    2007-2008
# 179449  Monsieur              Bindschaedler Vincent    2007-2008
# 178271  Monsieur             Boéchat Marc-Alexandre    2007-2008
# 171619  Monsieur               Buchschacher Nicolas    2007-2008
# 178786  Monsieur                       Coiro Andrea    2007-2008
# 178656  Monsieur                  Curreli Alexandre    2007-2008
# 178706    Madame                Falbriard Stéphanie    2007-2008
# 178553  Monsieur                 Bloch Marc-Olivier    2007-2008
# 181121  Monsieur                         Frund Loïc    2007-2008
# 181115  Monsieur  Miraglia Franco de Carvalho Pedro    2007-2008
# 178682  Monsieur                       Zoller Roman    2007-2008
# 180854  Monsieur                    Vautherin Jonas    2007-2008
# 180241  Monsieur              Sondag Pierre-Antoine    2007-2008
# 178684  Monsieur                     Schwery Thomas    2007-2008
# 178948  Monsieur                   Schädeli Andreas    2007-2008
# 171195  Monsieur                     Richter Arnaud    2007-2008
# 180959  Monsieur                   Restani Stéphane    2007-2008
# 179988    Madame                    Portmann Joëlle    2007-2008
# 179194  Monsieur                      Obrist Damien    2007-2008
#
#        graduation year  duration
# sciper
# 169569       2009-2010         3
# 180570       2009-2010         3
# 175190       2009-2010         3
# 181298       2009-2010         3
# 181248       2009-2010         3
# 178433       2009-2010         3
# 180731       2009-2010         3
# 179449       2009-2010         3
# 178271       2009-2010         3
# 171619       2009-2010         3
# 178786       2009-2010         3
# 178656       2009-2010         3
# 178706       2009-2010         3
# 178553       2009-2010         3
# 181121       2009-2010         3
# 181115       2009-2010         3
# 178682       2009-2010         3
# 180854       2009-2010         3
# 180241       2009-2010         3
# 178684       2009-2010         3
# 178948       2009-2010         3
# 171195       2009-2010         3
# 180959       2009-2010         3
# 179988       2009-2010         3
# 179194       2009-2010         3

# %%
students['civility'].value_counts(normalize=True, sort=True, ascending=True)
# Out:
# Madame      0.073048
# Monsieur    0.926952
# Name: civility, dtype: float64

# %% [markdown]
# The above results let us know that women actually represent a minority when it comes to the gender of the students taking a Bachelor at EPFL.

# %% [markdown]
# To get an idea of how long each gender takes to complete the Bachelor, we first group the records by gender and then plot the duration of the studies for each gender.

# %%
grouped_by_gender = students.groupby(['civility'])

plt.figure(figsize=(16,9))
ax1 = plt.subplot(211)
ax_female = grouped_by_gender.get_group('Madame').groupby(['duration']).count().name.plot(kind='bar', grid=True)
ax_female.set(xlabel='duration (years)', ylabel='number of female students')

plt.subplot(212, sharex=ax1)
ax_male = grouped_by_gender.get_group('Monsieur').groupby(['duration']).count().name.plot(kind='bar', grid=True)
ax_male.set(xlabel='duration (years)', ylabel='number of male students')
# Out:
# [<matplotlib.text.Text at 0x1d6ddd314e0>,
#  <matplotlib.text.Text at 0x1d6dc846438>]

# %% [markdown]
# By analysing the plots, we observe that the majority of the students take the expected 3 years to finish the Bachelor in Computer Science.

# %%
students.groupby(['civility'])[['duration']].mean().round(3)
# Out:
#           duration
# civility
# Madame       3.310
# Monsieur     3.481

# %% [markdown]
# By computing the average duration of the Bachelor studies for each gender, we observe that male students tend to take longer to obtain their Bachelor degree.

# %%
students['sex'] = (students['civility'] == 'Monsieur').astype(int)

# %% [markdown]
# We will do two test :
#     - chi_sqare test to know if the random variables sex and duration are independants, chi square is a parametric test.
#     -then we wwill do a ks test to know if the boths distribution ( for men and women ) follow the same rules.

# %%
import scipy.stats as sts

obs = np.array([students['sex'], students['duration']])
g, p, dof, expctd = sts.chi2_contingency(obs)
print('p-value is  : ' , p)
# Out:
# p-value is  :  1.0

# %% [markdown]
# As expected, given the high p-value, the test result does not detect a significant relationship between the variables.

# %%
rvs1 = students[students['civility']== 'Madame']['duration']
rvs2 = students[students['civility']== 'Monsieur']['duration']
sts.ks_2samp(rvs1, rvs2)
# Out:
# Ks_2sampResult(statistic=0.077398800599700168, pvalue=0.99572515917079174)

# %% [markdown]
# If the K-S statistic is small or the p-value is high, then we cannot reject the hypothesis that the distributions of the two samples are the same.
# This is the two-sided test, one-sided tests are not implemented. The test uses the two-sided asymptotic Kolmogorov-Smirnov distribution.
#
#
# Both of the test give us the same result women and men take the same time to finish their studies.

# %% [markdown]
# # Exercise 2

# %% [markdown]
# First step is to get all the student that made a master semester 1, 2 and 3. We store these students in 3 different dataframes student_ma1, student_ma2 and student_ma3.
#
# We do the same for the 2 master project (autumn and spring).

# %%
# ==================================================================================
# /!\ Quite slow to get the data, so try to not execute this cell too many times /!\
# ==================================================================================

student_ma1 = getDataFrame(all_years, [getCode(all_semesters, 'master1')])
student_ma2 = getDataFrame(all_years, [getCode(all_semesters, 'master2')])
student_ma3 = getDataFrame(all_years, [getCode(all_semesters, 'master3')])
student_maP_aut = getDataFrame(all_years, [getCode(all_semesters, 'project_autumn')])
student_maP_spr = getDataFrame(all_years, [getCode(all_semesters, 'project_spring')])

# %% [markdown]
# Let's start to manage data:
# In order to have a better view of the data, we sort them by the academic year in our 5 dataframes.

# %%
student_ma1.sort_values('academic year', inplace=True)
student_ma2.sort_values('academic year', inplace=True)
student_ma3.sort_values('academic year', inplace=True)
student_maP_aut.sort_values('academic year', inplace=True)
student_maP_spr.sort_values('academic year', inplace=True)

# %% [markdown]
# Sometimes a student can do the "master semester 1" more than once, if he fails its year and restart it the year after. In this case, we only want to keep the first "master semester 1" that he did here. Indeed, we want to compute the total time he spent at the EPFL.
# But for the two other dataframes, we want the opposite: keeping the last semester the student did here.

# %%
student_ma1.drop_duplicates(subset=['sciper'], keep='first', inplace=True)
student_ma2.drop_duplicates(subset=['sciper'], keep='last', inplace=True)
student_ma3.drop_duplicates(subset=['sciper'], keep='last', inplace=True)

# %% [markdown]
# The sciper is already unique for the two dataframes with students doing their master project.

# %%
print(student_maP_aut.sciper.is_unique)
print(student_maP_spr.sciper.is_unique)
# Out:
# True
# True

# %% [markdown]
# Now we can use the sciper number as index because it should be unique for each dataframe. It is going to be useful to make the concatenation.

# %%
student_ma1.set_index('sciper', inplace=True)
student_ma2.set_index('sciper', inplace=True)
student_ma3.set_index('sciper', inplace=True)
student_maP_aut.set_index('sciper', inplace=True)
student_maP_spr.set_index('sciper', inplace=True)

# %% [markdown]
# The goal being to find the duration spent at the EPFL for each student, we have to clean a little bit the dataframes.
#
# We make the assumption that if a student chose a minor or a specialization in the semester 1, this minor/specialization will still be present for him in the semester 2. So we can drop those 2 columns in the student_ma1 dataframe.
# Likewise, we can drop the columns name and civility in the student_ma2.
#
# For the 3 other dataframes, we only need to keep the year associated to the sciper number. So we drop the other columns.

# %%
student_ma1.drop('minor', axis=1, inplace=True)
student_ma1.drop('specialization', axis=1, inplace=True)
student_ma1.drop('semester', axis=1, inplace=True)

student_ma2.drop('civility', axis=1, inplace=True)
student_ma2.drop('name', axis=1, inplace=True)
student_ma2.drop('semester', axis=1, inplace=True)

student_ma3 = student_ma3.loc[:, ['academic year']]
student_maP_aut = student_maP_aut.loc[:, ['academic year']]
student_maP_spr = student_maP_spr.loc[:, ['academic year']]

# %% [markdown]
# To display it properly, let's rename the columns before concatenating the dataframes and reordering their columns.

# %%
student_ma1.columns = ['semester 1', 'civility', 'name']
student_ma2.columns = ['semester 2', 'minor', 'specialization']
student_ma3.columns = ['semester 3']
student_maP_aut.columns = ['project aut']
student_maP_spr.columns = ['project spr']

students = pd.concat([student_ma1, student_ma2], axis=1, join="inner")
students = pd.concat([students,student_ma3, student_maP_aut, student_maP_spr] , axis = 1)

# Reordering the columns
students = students[['civility', 'name', 'semester 1', 'semester 2','semester 3','project aut','project spr', 'minor', 'specialization']]

students.dropna(subset = ['civility'] , inplace = True)
students.fillna(value='',inplace = True)

students.head(100)
# Out:
#         civility                         name semester 1 semester 2  \
# 146330  Monsieur             Cardinaux Damien  2007-2008  2007-2008
# 146742  Monsieur                 Marx Clément  2008-2009  2009-2010
# 146929  Monsieur                Junod Antoine  2007-2008  2007-2008
# ...                                ...
# 167439
# 167447
# 167530
# 167845
# 169569  Signals, Images and Interfaces
# 169702
# 169734                    Biocomputing
# 169795
# 169839
# 169942
# 170176
# 170218
# 170219
# 170220
# 170222  Signals, Images and Interfaces
# 170224  Signals, Images and Interfaces
# 170225
# 170226         Foundations of Software
# 170235
# 170239
# 170241
# 170242
# 170265
# 170267         Foundations of Software
# 170403              Internet computing
# 170414              Internet computing
# 170451
# 170530
# 170646
# 170654              Internet computing
#
# [100 rows x 9 columns]

# %% [markdown]
# In order to compute the duration that each student spend at the EPFL we worked with those steps :
# - First we set the duration depending on how many years there is between the first and second semester. Some students did their second semester before the first one.
# - If the student did a semester 3 we add 6 months (0.5 year)
# - Otherwise, if the student do not have a semester 3 but have done a specialization or a minor (that should not happen !), we also add 6 months
# - Then, for each project master the student did (some student have both in autumn and spring), we add 6 months.
# - Last possibility is that the student did not mentioned his project master. In this case we make the assumption that he did one once as soon as the master thesis is mandatory at the EPFL. So we also add 6 months.

# %%
def getDuration(sem1, sem2):
    if int(sem2[0]) >= int(sem1[0]):
        return int(sem2[1]) - int(sem1[0])
    else: 
        return int(sem1[0]) - int(sem2[0])

students['duration'] = [getDuration(sem1.split("-"), sem2.split('-'))
                        for sem1, sem2 in students[['semester 1', 'semester 2']].values]

for i,row in students.iterrows() : 
    if (row['semester 3'] != '') :
        students.loc[i,'duration'] += 0.5
    elif ((row['minor'] != '' or row['specialization'] != '')) : 
        students.loc[i,'duration'] += 0.5
    if (row['project aut'] != '') :
        students.loc[i,'duration'] += 0.5     
    if (row['project spr'] != '') :
        students.loc[i,'duration'] += 0.5
    if (row['project spr'] == '' and row['project aut'] == '' ) :
        students.loc[i,'duration'] += 0.5

students
# Out:
#         civility                                  name semester 1 semester 2  \
# 146330  Monsieur                      Cardinaux Damien  2007-2008  2007-2008
# 146742  Monsieur                          Marx Clément  2008-2009  2009-2010
# 146929  Monsieur                         Junod Antoine  2007-2008  2007-2008
# 147008  Monsieur                           Good Xavier  2011-2012  2012-2013
# 152232  Monsieur                    Anagnostaras David  2007-2008  2007-2008
# 153066  Monsieur             Aeberhard François-Xavier  2007-2008  2009-2010
# 153746  Monsieur                          Cassina Ilya  2007-2008  2007-2008
# 153762  Monsieur                          Conus Johann  2008-2009  2009-2010
# 154080  Monsieur                   Fomene Tierry Alain  2007-2008  2008-2009
# 154573    Madame                    Benabdallah Zeineb  2007-2008  2008-2009
# 154643  Monsieur                           Dumont Loïc  2007-2008  2007-2008
# 154706  Monsieur                        Suter François  2007-2008  2007-2008
# 155018  Monsieur                          Signori Jean  2007-2008  2007-2008
# 155097  Monsieur                               Wei Zhe  2007-2008  2007-2008
# 159516  Monsieur                           Raja Yanick  2008-2009  2008-2009
# 159998    Madame                           Jesse Julia  2008-2009  2008-2009
# 160148    Madame                       Casati Nathalie  2007-2008  2007-2008
# 160213  Monsieur                    Bécholey Alexandre  2008-2009  2008-2009
# 160225  Monsieur                     Cassata Alexandre  2007-2008  2007-2008
# 160254  Monsieur                         Kohler Johann  2007-2008  2007-2008
# 160492  Monsieur                           Bettex Marc  2007-2008  2007-2008
# 184991  2012-2013
# 185283  2014-2015
# 174036
# 186833  2013-2014
# 195446  2014-2015
# 180731  2011-2012               2011-2012
# 170946  2016-2017
#
#                         specialization  duration
# 154573                    Biocomputing       3.0
# 169734                    Biocomputing       3.0
# 224627       Computer Engineering - SP       2.0
# 178271       Computer Engineering - SP       2.0
# 223825       Computer Engineering - SP       2.0
# 178283       Computer Engineering - SP       2.0
# 217301       Computer Engineering - SP       3.0
# 216690       Computer Engineering - SP       3.0
# 244206       Computer Engineering - SP       2.0
# 214225       Computer Engineering - SP       3.0
# 183984       Computer Engineering - SP       3.0
# 211672       Computer Engineering - SP       2.0
# 185005       Computer Engineering - SP       3.0
# 211478       Computer Engineering - SP       2.0
# 185458       Computer Engineering - SP       2.0
# 191354       Computer Engineering - SP       3.0
# 201034       Computer Engineering - SP       3.0
# 218353       Computer Engineering - SP       3.0
# 221295       Computer Engineering - SP       2.0
# 227443         Computer Science Theory       2.0
# 225757                  Data Analytics       2.0
# 202973                  Data Analytics       2.0
# 214573                  Data Analytics       2.0
# 256553                  Data Analytics       2.0
# 224356                  Data Analytics       2.0
# 205653         Foundations of Software       3.0
# 226421         Foundations of Software       3.0
# 186250         Foundations of Software       3.0
# 206692         Foundations of Software       3.0
# 211123         Foundations of Software       2.0
# ...                                ...       ...
# 224520              Internet computing       2.0
# 181244              Internet computing       4.0
# 188002              Internet computing       2.0
# 190822              Internet computing       2.0
# 186426              Internet computing       3.0
# 186067              Internet computing       3.0
# 227660              Internet computing       2.0
# 185991              Internet computing       3.0
# 228358              Internet computing       2.0
# 230947              Internet computing       3.0
# 233454              Internet computing       3.0
# 184956              Internet computing       3.0
# 234285              Internet computing       3.0
# 184264              Internet computing       3.0
# 183534              Internet computing       3.0
# 186598              Internet computing       3.0
# 174456                 Service science       2.0
# 202059                 Service science       3.0
# 254809  Signals, Images and Interfaces       2.0
# 238199  Signals, Images and Interfaces       3.0
# 146742  Signals, Images and Interfaces       3.5
# 185161  Signals, Images and Interfaces       2.0
# 184814  Signals, Images and Interfaces       3.0
# 184991  Signals, Images and Interfaces       3.0
# 185283  Signals, Images and Interfaces       3.0
# 174036  Signals, Images and Interfaces       2.0
# 186833  Signals, Images and Interfaces       3.0
# 195446  Signals, Images and Interfaces       2.0
# 180731  Signals, Images and Interfaces       2.0
# 170946  Signals, Images and Interfaces       3.0
#
# [180 rows x 10 columns]

# %% [markdown]
# Now we can compare visually how many years students stayed at the EPFL, depending on their specialization.

# %%
means_specialization = students_with_specialization.groupby(['specialization'])['duration']

fig, ax = plt.subplots(figsize=(12,6))
means_specialization.mean().plot(ax=ax, kind='bar', legend=False, grid=True).set_ylabel('duration (years)')

# %%
from scipy import stats
rvs1 =means_specialization.mean()
rvs2 = means_specialization.mean().mean()*np.ones(11)
stats.ks_2samp(rvs1, rvs2)

# %% [markdown]
# If the K-S statistic is small or the p-value is high, then we cannot reject the hypothesis that the distributions of the two samples are the same.
# The distribtion is not uniform which means that there are sections which takes more time than the other.
#
# BUT : this is hard to compute relevant test given that we have few samples for biocomputing.
# The result of the test should be taken with caution BUT Biocomputing seems harder

# %% [markdown]
# # Bonus

# %% [markdown]
# We start by figuring out how many records correspond to male and female Master students.

# %%
students.groupby(['civility'])[['name']].count()

# %% [markdown]
# Male students clearly outnumber female students when it comes to the Master studies.

# %% [markdown]
# Let's now take a look at the distribution of the duration of the stay at EPFL to take a Master degree according to gender.

# %%
master_grouped_by_gender = students.groupby(['civility'])

plt.figure(figsize=(16,9))
ax1 = plt.subplot(211)
ax_female = master_grouped_by_gender.get_group('Madame').groupby(['duration']).count().name.plot(kind='bar', grid=True)
ax_female.set(xlabel='duration (years)', ylabel='number of female students')

plt.subplot(212, sharex=ax1)
ax_male = master_grouped_by_gender.get_group('Monsieur').groupby(['duration']).count().name.plot(kind='bar', grid=True)
ax_male.set(xlabel='duration (years)', ylabel='number of male students')

# %% [markdown]
# Most students (both female and male) take 2 years to complete their Master studies, which is the expected duration for the ones following the 90 ECTS program. Taking a Minor or a Specialization might justify the fact that students who take 3 years to complete the Master are the second most frequent.

# %%
students.groupby(['civility'])[['duration']].mean().round(3)

# %% [markdown]
# In average, female students take a little longer than male students to conclude their Master studies at EPFL.

# %% [markdown]
# Similar to what was done to compute the duration of the stay of each student at EPFL, we compare the entries from the first and the second semester to get the year when each student started its Master studies.

# %%
def get_first_year(sem1, sem2):
    if int(sem2[0]) >= int(sem1[0]):
        return int(sem1[0])
    else: 
        return int(sem2[0])

students['first year'] = [get_first_year(sem1.split("-"), sem2.split('-'))
                          for sem1, sem2 in students[['semester 1', 'semester 2']].values]

# %% [markdown]
# We now compute the average stay of Master students at EPFL according to the year when they started their studies.

# %%
grouped_by_year = students.groupby(['first year'])

fig, ax = plt.subplots(figsize=(12,6))
grouped_by_year.mean().plot(ax=ax, kind='bar', grid=True, legend=False).set_ylabel('average duration (years)')

# %% [markdown]
# Students who started their Master in 2014 took, in average, more time to complete it.

# %% [markdown]
# We also want to identify changes over time. To do so, we start by plotting the duration of Master studies of each student according to the year when they started their studies.

# %%
fig, ax = plt.subplots(figsize=(12,6))

colors = {'Madame':'red', 'Monsieur':'blue'}
grouped_by_gender = students.groupby(['civility'])

for key, gender in grouped_by_gender:
    gender.plot(ax=ax, kind='scatter', x='first year', y='duration', label=key, color=colors[key])

plt.show()

# %% [markdown]
# Let's now take a look at the average stay according to gender and first year of Master studies.

# %%
grouped_by_gender_year = students.groupby(['first year', 'civility'])

fig, ax = plt.subplots(figsize=(12,6))
grouped_by_gender_year.mean().plot(ax=ax, kind='bar', color=['r','b']*9, grid=True, legend=False).set_ylabel('average duration (years)')

# %% [markdown]
# The year of 2008 seems to be the one when a larger difference in average graduation time between female and male students was recorded. This difference seems to be getting smaller.

# %%
fig, ax = plt.subplots(figsize=(12,6))
grouped_by_gender_year.median().plot(ax=ax, kind='bar', color=['r','b']*9, legend=False).set_ylabel('median duration (years)')

# %% [markdown]
# If we now take a look at the median duration throughout the years, we note that 2012 was the year when the discrepancy between genders was the biggest. Apart from this year and 2007, the median is equal for both genders.

# %% [markdown]
# We can conclude that students who started their Master in 2012 or 2014 where the ones taking the longest to graduate. One must note that students who started their studies in 2015 might not have finished their Master yet and that can affect the results here displayed.
